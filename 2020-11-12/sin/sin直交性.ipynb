# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

xs = np.linspace(-np.pi, np.pi, 100)
sinx = np.sin(xs)
cosx = np.cos(xs)

plt.plot(xs, sinx)
plt.plot(xs, cosx)

np.round(sinx.dot(cosx), 10)
# Out:
# 0.0
